# %% [markdown]
# ## Dependencias

# %%
# %pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (0.10.18)
# Requirement already satisfied: opencv-python in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: pandas in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: absl-py in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.35)
# Requirement already satisfied: jaxlib in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.35)
# Requirement already satisfied: matplotlib in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: numpy<2 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.25.5)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.4.0 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (0.5.0)
# Requirement already satisfied: opt-einsum in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (3.1.4)
# Requirement already satisfied: pycparser in c:\users\maste\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle 
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %% [markdown]
# ## Lectura del Dataset .CSV

# %%
df = pd.read_csv('../Generador_db/letters_mst.csv')

# %%
df['class'] = df['class'].astype(str)

# %%
print(df['class'].unique())
# Out:
# ['M' 'N' 'Q' 'A' 'B' 'C' 'D' 'E' 'F' 'G' 'H' 'I' 'J' 'K' 'L' 'O' 'P' 'R'
#  'S' 'T' 'U' 'V' 'W' 'X' 'Y' 'Z']

# %%
df.head()
# Out:
#   class        x1        y1            z1        x2        y2        z2  \
# 0     M  0.661018  0.375744 -7.742822e-07  0.627745  0.424952 -0.030079
# 1     M  0.659391  0.370549 -6.462180e-07  0.631015  0.410770 -0.030986
# 2     M  0.656762  0.368513 -6.362934e-07  0.627994  0.405590 -0.032197
# 3     M  0.652830  0.374881 -6.363881e-07  0.619746  0.403536 -0.028919
# 4     M  0.639488  0.366715 -5.760666e-07  0.656109  0.406463 -0.033049
#
#          x3        y3        z3  ...       z18       x19       y19       z19  \
# 0  0.610444  0.498416 -0.069147  ... -0.105239  0.697227  0.563546 -0.126251
# 1  0.612750  0.476740 -0.068882  ... -0.097236  0.699666  0.542939 -0.115719
# 2  0.607093  0.467477 -0.069235  ... -0.097999  0.696975  0.538272 -0.118480
# 3  0.598951  0.462873 -0.063610  ... -0.096865  0.693011  0.546682 -0.117292
# 4  0.661423  0.477370 -0.072682  ... -0.096612  0.593188  0.533279 -0.109674
#
#         x20       y20       z20       x21       y21       z21
# 0  0.689137  0.628183 -0.117348  0.678979  0.675698 -0.109039
# 1  0.689317  0.590956 -0.108517  0.680005  0.623269 -0.101943
# 2  0.689799  0.586549 -0.112394  0.681523  0.619191 -0.106441
# 3  0.681884  0.594556 -0.110879  0.672114  0.626906 -0.104569
# 4  0.583095  0.578797 -0.100160  0.575558  0.611310 -0.093287
#
# [5 rows x 64 columns]

# %%
df.tail()
# Out:
#       class        x1        y1            z1        x2        y2        z2  \
# 33174     Z  0.727733  0.655391 -5.635695e-08  0.702387  0.616539 -0.034974
# 33175     Z  0.726333  0.645918 -4.720752e-08  0.701028  0.608635 -0.035029
# 33176     Z  0.718419  0.632339 -3.360524e-08  0.692725  0.594525 -0.033915
# 33177     Z  0.716241  0.623507  7.636889e-09  0.690806  0.587307 -0.037228
# 33178     Z  0.718441  0.620459 -2.470159e-08  0.692683  0.585284 -0.036285
#
#              x3        y3        z3  ...       z18       x19       y19  \
# 33174  0.696931  0.553352 -0.058153  ... -0.051100  0.825231  0.529836
# 33175  0.695755  0.545205 -0.058039  ... -0.049931  0.821899  0.518968
# 33176  0.687807  0.529316 -0.056468  ... -0.052652  0.815537  0.506027
# 33177  0.685031  0.523459 -0.061506  ... -0.051635  0.814398  0.492927
# 33178  0.686463  0.521043 -0.060370  ... -0.051594  0.815800  0.491843
#
#             z19       x20       y20       z20       x21       y21       z21
# 33174 -0.076590  0.799192  0.568301 -0.066636  0.785043  0.573759 -0.053485
# 33175 -0.075938  0.796091  0.558071 -0.065742  0.782810  0.563115 -0.052130
# 33176 -0.078551  0.788977  0.544399 -0.067766  0.775933  0.549706 -0.054013
# 33177 -0.080248  0.789116  0.534152 -0.069630  0.775455  0.541445 -0.055166
# 33178 -0.080330  0.789873  0.532440 -0.070019  0.777036  0.536949 -0.056117
#
# [5 rows x 64 columns]

# %%
print(df.columns)
# Out:
# Index(['class', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 'x4',
#        'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7', 'y7', 'z7', 'x8',
#        'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10', 'x11', 'y11', 'z11',
#        'x12', 'y12', 'z12', 'x13', 'y13', 'z13', 'x14', 'y14', 'z14', 'x15',
#        'y15', 'z15', 'x16', 'y16', 'z16', 'x17', 'y17', 'z17', 'x18', 'y18',
#        'z18', 'x19', 'y19', 'z19', 'x20', 'y20', 'z20', 'x21', 'y21', 'z21'],
#       dtype='object')

# %%
df[df['class']== 'X']
# Out:
#       class        x1        y1            z1        x2        y2        z2  \
# 29967     X  0.428739  0.801486 -1.637130e-07  0.400278  0.728285 -0.003980
# 29968     X  0.428739  0.801486 -1.637130e-07  0.400278  0.728285 -0.003980
# 29969     X  0.423116  0.801408 -1.881212e-07  0.389329  0.722440 -0.001509
# 29970     X  0.421540  0.799858 -1.990760e-07  0.390098  0.717227 -0.000328
# 29971     X  0.420739  0.804283 -2.440133e-07  0.386227  0.720261  0.001560
# ...     ...       ...       ...           ...       ...       ...       ...
# 31031     X  0.827457  0.610181 -2.572114e-07  0.816474  0.565451  0.001332
# 31032     X  0.827457  0.610181 -2.572114e-07  0.816474  0.565451  0.001332
# 31033     X  0.846276  0.617847 -2.267013e-07  0.843840  0.572886  0.002265
# 31034     X  0.848638  0.615775 -2.196330e-07  0.832661  0.571478  0.000094
# 31035     X  0.848638  0.615775 -2.196330e-07  0.832661  0.571478  0.000094
#
#              x3        y3        z3  ...       z18       x19       y19  \
# 29967  0.364252  0.669135 -0.026897  ... -0.093608  0.326509  0.748567
# 29968  0.364252  0.669135 -0.026897  ... -0.093608  0.326509  0.748567
# 29969  0.355474  0.659664 -0.025591  ... -0.102024  0.312964  0.732654
# 29970  0.356224  0.652563 -0.024261  ... -0.100806  0.313113  0.727662
# 29971  0.353197  0.654140 -0.022760  ... -0.106066  0.313425  0.724180
# ...         ...       ...       ...  ...       ...       ...       ...
# 31031  0.812714  0.520858 -0.001493  ... -0.031355  0.794589  0.552005
# 31032  0.812714  0.520858 -0.001493  ... -0.031355  0.794589  0.552005
# 31033  0.837968  0.528188 -0.001114  ... -0.032698  0.813999  0.554065
# 31034  0.828305  0.528189 -0.004049  ... -0.033154  0.821615  0.558485
# 31035  0.828305  0.528189 -0.004049  ... -0.033154  0.821615  0.558485
#
#             z19       x20       y20       z20       x21       y21       z21
# 29967 -0.106429  0.339577  0.774376 -0.094134  0.364659  0.770265 -0.083876
# 29968 -0.106429  0.339577  0.774376 -0.094134  0.364659  0.770265 -0.083876
# 29969 -0.112291  0.327870  0.757578 -0.098114  0.354586  0.753718 -0.087703
# 29970 -0.111377  0.327171  0.753411 -0.097212  0.353884  0.751364 -0.086427
# 29971 -0.115585  0.325385  0.749909 -0.100456  0.351436  0.747350 -0.089414
# ...         ...       ...       ...       ...       ...       ...       ...
# 31031 -0.038187  0.796699  0.567006 -0.034314  0.808099  0.571059 -0.030644
# 31032 -0.038187  0.796699  0.567006 -0.034314  0.808099  0.571059 -0.030644
# 31033 -0.038958  0.816250  0.568441 -0.035008  0.827483  0.572709 -0.031576
# 31034 -0.040456  0.822172  0.573420 -0.036258  0.833021  0.577645 -0.032311
# 31035 -0.040456  0.822172  0.573420 -0.036258  0.833021  0.577645 -0.032311
#
# [1069 rows x 64 columns]

# %% [markdown]
# ### Segmentación del DB

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
y
# Out:
# 0        M
# 1        M
# 2        M
# 3        M
# 4        M
#         ..
# 33174    Z
# 33175    Z
# 33176    Z
# 33177    Z
# 33178    Z
# Name: class, Length: 33179, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 24299    S
# 18349    K
# 22117    O
# 30208    X
# 32230    Z
#         ..
# 19874    L
# 22149    O
# 6611     C
# 31804    Y
# 24917    S
# Name: class, Length: 9954, dtype: object

# %% [markdown]
# ## Entrenamiento ML

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['S', 'K', 'O', ..., 'C', 'Y', 'S'], dtype='<U1')

# %% [markdown]
# ## Evaluación y Serialización

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9971870604781997
# rc 0.9820172794856339
# rf 0.995177817962628
# gb 0.9911593329314848

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['S', 'K', 'O', ..., 'C', 'Y', 'S'], dtype=object)

# %%
y_test
# Out:
# 24299    S
# 18349    K
# 22117    O
# 30208    X
# 32230    Z
#         ..
# 19874    L
# 22149    O
# 6611     C
# 31804    Y
# 24917    S
# Name: class, Length: 9954, dtype: object

# %%
with open('modelo_letters.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)
